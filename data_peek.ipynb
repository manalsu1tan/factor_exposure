# %%
import pyarrow.parquet as pq

metadata = pq.read_table('/Users/Manal/factor_exposure/data/model/latest/factor_returns.parquet')
print(metadata)
# Out:
# pyarrow.Table
# date: date32[day]
# mom_12_1: double
# mom_6_1: double
# rev_1m: double
# beta_spy_252: double
# vol_63: double
# liq_dollarvol_21: double
# ----
# date: [[2016-02-17,2016-02-18,2016-02-19,2016-02-22,2016-02-23,...,2026-02-09,2026-02-10,2026-02-11,2026-02-12,2026-02-13]]
# mom_12_1: [[0,0,0,0,0,...,0.015366132658863321,-0.001226548781177234,-0.016059676008411898,0.010581696395479932,0.0009114003441185967]]
# mom_6_1: [[0,0,0,0,0,...,-0.015068974031872078,-0.0037856270120465007,0.008096967072145638,-0.0019166353985901148,-0.001830206892241208]]
# rev_1m: [[0,0,0,0,0,...,-0.008411106044704634,-0.0026981852447875037,-0.016676651480175726,0.004729534586305031,0.007249736773589167]]
# beta_spy_252: [[0,0,0,0,0,...,-0.014585430211492313,-0.005652259965359888,-0.00022229902750494268,-0.011536629500980907,-0.004926847345502607]]
# vol_63: [[0,0,0,0,0,...,0.011403692708127218,-0.00220373365954779,0.006236124802066122,0.016232077598713698,0.00639895359857763]]
# ...
